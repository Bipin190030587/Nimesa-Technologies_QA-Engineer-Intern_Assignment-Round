# %%
import requests

API_BASE_URL = "https://samples.openweathermap.org/data/2.5/forecast/hourly?q=London,us&appid=b6907d289e10d714a6e88b30761fae22"

def get_weather_data():
    response = requests.get(API_BASE_URL)
    if response.status_code == 200:
        data = response.json()
        return data
    else:
        print("Failed to fetch weather data.")
        return None

def get_option_from_user():
    print("1. Get weather")
    print("2. Get Wind Speed")
    print("3. Get Pressure")
    print("0. Exit")
    return int(input("Enter your choice: "))

def get_date_from_user():
    return input("Enter the date (YYYY-MM-DD): ")

def get_hourly_weather_on_date(weather_data, date):
    for forecast in weather_data['list']:
        if forecast['dt_txt'].split()[0] == date:
            return forecast
    return None

def main():
    weather_data = get_weather_data()

    if weather_data is None:
        return

    while True:
        option = get_option_from_user()

        if option == 0:
            print("Exiting...")
            break
        elif option == 1:
            date = get_date_from_user()
            forecast = get_hourly_weather_on_date(weather_data, date)
            if forecast:
                print(f"Temperature on {date}: {forecast['main']['temp']} °C")
            else:
                print("Data not available for the given date.")
        elif option == 2:
            date = get_date_from_user()
            forecast = get_hourly_weather_on_date(weather_data, date)
            if forecast:
                print(f"Wind Speed on {date}: {forecast['wind']['speed']} m/s")
            else:
                print("Data not available for the given date.")
        elif option == 3:
            date = get_date_from_user()
            forecast = get_hourly_weather_on_date(weather_data, date)
            if forecast:
                print(f"Pressure on {date}: {forecast['main']['pressure']} hPa")
            else:
                print("Data not available for the given date.")
        else:
            print("Invalid option. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 1
# Enter the date (YYYY-MM-DD): 2019-03-27
# Temperature on 2019-03-27: 278.76 °C
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 2
# Enter the date (YYYY-MM-DD): 2019-03-27
# Wind Speed on 2019-03-27: 1.6 m/s
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 3
# Enter the date (YYYY-MM-DD): 2019-03-27
# Pressure on 2019-03-27: 1031.934 hPa
# 1. Get weather
# 2. Get Wind Speed
# 3. Get Pressure
# 0. Exit
# Enter your choice: 0
# Exiting...
